# %%
# !pip install torchvision

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch 
import os
import sys
#import torchvision
import numpy as np
import pickle
from PIL import Image

# %%
ID = "10"
input_dir = "/Users/harshjoon/Desktop/Github_repos/instrument_position_detection_using_ML/data/set_1/images/"
label_dir = "/Users/harshjoon/Desktop/Github_repos/instrument_position_detection_using_ML/data/set_1/labels/"

# %%
img = Image.open( input_dir + str(ID) + ".png" )
# img = torchvision.io.read_image(
#                 input_dir + str(ID) + ".png "
#             ).to(torch.float32)

# %%
plt.imshow(img)

# %%
img_arr = np.asarray(img)

# %%
plt.imshow(img_arr[:,:,1])

# %%
with open(label_dir + str(ID), 'rb') as fb:
    Y  = pickle.load(fb)
    
'''
LABEL
- location right
- location left
- rotation right
- rotation left
'''
# Out:
# '\nLABEL\n- location right\n- location left\n- rotation right\n- rotation left\n'

# %%
Y
# Out:
# [[0, 2.495596260903574, 0],
#  [0, -2.1107659870769506, 0],
#  [2.383916263487543, 0, 0],
#  [1.095709733221807, 0, 0]]

# %%
Y[0][1]
# Out:
# 2.495596260903574
